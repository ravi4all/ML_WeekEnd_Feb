# %%
import numpy as np
# %matplotlib inline


from pylab import *

x = np.random.normal(3.0,1.0,100)
y = np.random.normal(50,30,100)/x

scatter(x,y)

# %%
Xtrain = x[:80]
Ytrain = y[:80]

#print(Xtrain)
#print(Ytrain)

scatter(Xtrain,Ytrain)

# %%
Xtest = x[80:]
Ytest = y[80:]

#print(Xtest)
#print(Ytest)

scatter(Xtest,Ytest)
